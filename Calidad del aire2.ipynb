# %%
import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
import warnings
import sqlite3
import logging

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_calidad_del_aire = pd.read_csv('C:/Users/USUARIO/Documents/Analisis y visualizacion de datos/DATOS_DE_CALIDAD_DEL_AIRE_EN_COLOMBIA_2011-2018_20240918.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e:
    
    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:
    
    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_19564\161227968.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_calidad_del_aire = pd.read_csv('C:/Users/USUARIO/Documents/Analisis y visualizacion de datos/DATOS_DE_CALIDAD_DEL_AIRE_EN_COLOMBIA_2011-2018_20240918.csv')
# El dataset se cargó exitosamente.

# %%
#results_df['fecha'] = pd.to_datetime(results_df['fecha'])
df_calidad_del_aire['Fecha'] = pd.to_datetime(df_calidad_del_aire['Fecha'])
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_19564\1713198625.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_calidad_del_aire['Fecha'] = pd.to_datetime(df_calidad_del_aire['Fecha'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 #results_df['fecha'] = pd.to_datetime(results_df['fecha'])
# ----> 2 df_calidad_del_aire['Fecha'] = pd.to_datetime(df_calidad_del_aire['Fecha'])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# ...

# %%
df_calidad_del_aire.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20389245 entries, 0 to 20389244
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count     Dtype
# ---  ------                          --------------     -----
#  0   Fecha                           20389245 non-null  object
#  1   Autoridad Ambiental             20389245 non-null  object
#  2   Nombre de la estación           20389245 non-null  object
#  3   Tecnología                      15657064 non-null  object
#  4   Latitud                         20388880 non-null  float64
#  5   Longitud                        20388880 non-null  float64
#  6   Código del departamento         20388880 non-null  float64
#  7   Departamento                    20388880 non-null  object
#  8   Código del municipio            20388880 non-null  float64
#  9   Nombre del municipio            20388880 non-null  object
#  10  Tipo de estación                20388880 non-null  object
# ...

# %%
df_calidad_del_aire
# Out:
#                               Fecha Autoridad Ambiental Nombre de la estación  \
# 0         09/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 1         13/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 2         15/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 3         18/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 4         20/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# ...                             ...                 ...                   ...
# 20389240           27/12/2018 00:00                 SDA               Usaquén
# 20389241           28/12/2018 00:00                 SDA               Usaquén
# 20389242           29/12/2018 00:00                 SDA               Usaquén
# 20389243           30/12/2018 00:00                 SDA               Usaquén
# 20389244           31/12/2018 00:00                 SDA               Usaquén
#
# ...

# %%
df_calidad_del_aire=pd.DataFrame(df_calidad_del_aire)
num_rows, num_cols=df_calidad_del_aire.shape
print(f'El Dataframe, tiene {num_rows} filas {num_cols} columnas.')
# Out:
# El Dataframe, tiene 20389245 filas 16 columnas.

# %%
df_calidad_del_aire=df_calidad_del_aire.drop(['Código del departamento','Código del municipio'],axis=1)

# %%
df_calidad_del_aire.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20389245 entries, 0 to 20389244
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count     Dtype
# ---  ------                          --------------     -----
#  0   Fecha                           20389245 non-null  object
#  1   Autoridad Ambiental             20389245 non-null  object
#  2   Nombre de la estación           20389245 non-null  object
#  3   Tecnología                      15657064 non-null  object
#  4   Latitud                         20388880 non-null  float64
#  5   Longitud                        20388880 non-null  float64
#  6   Departamento                    20388880 non-null  object
#  7   Nombre del municipio            20388880 non-null  object
#  8   Tipo de estación                20388880 non-null  object
#  9   Tiempo de exposición            20389245 non-null  int64
#  10  Variable                        20389245 non-null  object
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x)
df_calidad_del_aire.describe()
# Out:
#          Latitud   Longitud  Tiempo de exposición  Concentración
# count 20388880.0 20388880.0            20389245.0     19006859.0
# mean         5.9      -74.6                   1.6          128.5
# std          1.9        1.1                   3.3          529.9
# min          1.2      -77.3                   1.0          -35.7
# 25%          4.6      -75.6                   1.0            3.9
# 50%          6.0      -74.1                   1.0           24.1
# 75%          6.3      -74.1                   1.0           74.5
# max         11.5      -70.8                  24.0       733378.0

# %%
df_calidad_del_aire.rename(columns={
                                    'Nombre de la estación': 'Estación',
                                    'Nombre del municipio' : 'Municipio'
}, inplace=True)

# %%
df_calidad_del_aire.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20389245 entries, 0 to 20389244
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count     Dtype
# ---  ------                          --------------     -----
#  0   Fecha                           20389245 non-null  object
#  1   Autoridad Ambiental             20389245 non-null  object
#  2   Estación                        20389245 non-null  object
#  3   Tecnología                      15657064 non-null  object
#  4   Latitud                         20388880 non-null  float64
#  5   Longitud                        20388880 non-null  float64
#  6   Departamento                    20388880 non-null  object
#  7   Municipio                       20388880 non-null  object
#  8   Tipo de estación                20388880 non-null  object
#  9   Tiempo de exposición            20389245 non-null  int64
#  10  Variable                        20389245 non-null  object
# ...

# %%
df_calidad_del_aire.head(3)
# Out:
#                        Fecha Autoridad Ambiental             Estación  \
# 0  09/04/2011 12:00:00 a. m.                AMVA  BAR-Hosp. S.V. Paul
# 1  13/04/2011 12:00:00 a. m.                AMVA  BAR-Hosp. S.V. Paul
# 2  15/04/2011 12:00:00 a. m.                AMVA  BAR-Hosp. S.V. Paul
#
#   Tecnología  Latitud  Longitud Departamento Municipio Tipo de estación  \
# 0     Manual      6.4     -75.3    ANTIOQUIA   BARBOSA             Fija
# 1     Manual      6.4     -75.3    ANTIOQUIA   BARBOSA             Fija
# 2     Manual      6.4     -75.3    ANTIOQUIA   BARBOSA             Fija
#
#    Tiempo de exposición Variable Unidades  Concentración  \
# 0                    24     PM10    µg/m3           55.6
# 1                    24     PM10    µg/m3           30.8
# 2                    24     PM10    µg/m3           21.0
#
#   Nueva columna georreferenciada
# 0            (6.436, -75.333431)
# 1            (6.436, -75.333431)
# 2            (6.436, -75.333431)

# %%
print(df_calidad_del_aire['Fecha'].dtype)
# Out:
# object

# %%
df_calidad_del_aire['Fecha']=df_calidad_del_aire['Fecha'].dt.strftime('%D/%M/%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_calidad_del_aire['Fecha']=df_calidad_del_aire['Fecha'].dt.strftime('%D/%M/%Y')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
#resultado=resultado.drop('',axis=1)
#varias columnas
#resultado=resultado.drop(['',''],axis=1)

# %%
#Paso 1, Cargar datos.
#Paso 2:
#results_df['fecha'] = pd.to_datetime(results_df['fecha'])

#Paso 3:
#results_df['Anio'] = results_df['fecha'].dt.year
